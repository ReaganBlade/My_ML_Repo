# %% [markdown]
# # ML Model to Predict the Quality of Apples

# %% [markdown]
# ### importing data set

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("D:\\Personal\\Data Science\\DataSets\\apple_quality.csv")
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.dropna(inplace=True)

# %%
print(df)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
# transforming Data in Quality Column to 1s and 0s

df['Quality'] = df['Quality'].map({'good':1, 'bad':0})

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity  Quality
# ...

# %%
# data preparation
y = df['Quality']

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 3995    0
# 3996    1
# 3997    0
# 3998    1
# 3999    1
# Name: Quality, Length: 4000, dtype: int64

# %%
X = df.drop('Quality', axis=1)
X
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity
# ...

# %%
# Data Splitting

from sklearn.model_selection import train_test_split

X_train, X_test, y_test, y_train = train_test_split(X, y, test_size=0.5, random_state=100)

# %%
# print(X_train)
print(y_train)
# Out:
# 3218    1
# 883     0
# 367     1
# 2226    1
# 2578    1
#        ..
# 2596    1
# 710     0
# 2670    1
# 2609    0
# 3486    1
# Name: Quality, Length: 2000, dtype: int64

# %%
X_test
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3218  3218.0  1.152415  2.445003  -1.560773     3.790427  -0.266642 -1.537781
# 883    883.0  0.316580 -1.419343  -2.793662    -0.561515   2.987417  2.030203
# 367    367.0  3.284414 -4.159538  -2.261085     0.159527  -0.861256  2.510890
# 2226  2226.0 -0.514957  0.034978  -0.459916     1.291525   0.454004  1.536035
# 2578  2578.0 -0.041383 -1.816790  -0.210444     1.056712  -0.223427  2.863540
# ...      ...       ...       ...        ...          ...        ...       ...
# 2596  2596.0  3.046145 -4.690724   1.912361     3.455783  -1.667053  4.258164
# 710    710.0 -2.532792 -3.123672   1.117364    -0.279017   0.154359  1.752812
# 2670  2670.0 -0.819009 -0.780292   2.022567     1.394313  -0.903509  1.655351
# 2609  2609.0 -1.767223 -0.934014   0.531094     1.025545   1.699573 -1.215804
# 3486  3486.0 -2.055566  1.231102  -3.020160     2.019850  -2.959042 -0.845375
#
#            Acidity
# ...

# %%
# Model Building Using Linear Regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Applying the model to make a prediction
lrTrainPredict = lr.predict(X_train)
lrTestPredict = lr.predict(X_test)

# %%
print(lrTrainPredict)
# Out:
# [0.52153694 0.45342931 0.44511666 ... 0.50411108 0.39057364 0.46970498]

# %%
print(lrTestPredict)
# Out:
# [0.53990902 0.51254496 0.53534201 ... 0.46223436 0.55323528 0.53296877]

# %%
# Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error as mse, r2_score as r2s

lrTrainMse = mse(y_train, lrTrainPredict)
lrTrainR2 = r2s(y_train, lrTrainPredict)

lrTestMse = mse(y_test, lrTestPredict)
lrTestR2 = r2s(y_test, lrTestPredict)

# %%
print('LR MSE (Train): ', lrTrainMse)
print('LR R2 (Train): ', lrTrainR2)
print('LR MSE (Test): ',lrTestMse)
print('LR R2 (Test): ', lrTestR2)
# Out:
# LR MSE (Train):  0.24701757126948629
# LR R2 (Train):  0.01188129710561281
# LR MSE (Test):  0.25329850117069047
# LR R2 (Test):  -0.01331661599329692

# %%
lrResults = pd.DataFrame(["LinearRegression", lrTrainMse, lrTrainR2, lrTestMse, lrTestR2]).transpose()
lrResults.columns = ['Method', 'Training MSE', "Training R2", "Testing MSE", "Testing r2"]

# %%
lrResults
# Out:
#              Method Training MSE Training R2 Testing MSE Testing r2
# 0  LinearRegression     0.247018    0.011881    0.253299  -0.013317

# %%
# Random Forest
# Training Model 

from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
# applying the model to make a prediction

rfTrainPred = rf.predict(X_train)
rfTestPred = rf.predict(X_test)

# %%
# Evaluate Model Performance

from sklearn.metrics import mean_squared_error, r2_score

rfTrainMse = mean_squared_error(y_train, rfTrainPred)
rfTrainR2 = r2_score(y_train, rfTrainPred)

rfTestMse = mean_squared_error(y_test, rfTestPred)
rfTestR2 = r2_score(y_test, rfTestPred)

# %%
rfResults = pd.DataFrame(['Random Forest', rfTrainMse, rfTrainR2, rfTestMse, rfTestR2]).transpose()
rfResults.columns = ['Method', 'Training MSE', "Training R2", "Testing MSE", "Testing r2"]

rfResults
# Out:
#           Method Training MSE Training R2 Testing MSE Testing r2
# 0  Random Forest     0.243414    0.026295    0.250799  -0.003316

# %%
# Model Comparison

df_models = pd.concat([lrResults, rfResults], axis = 0)

df_models.reset_index(drop = True)
# Out:
#              Method Training MSE Training R2 Testing MSE Testing r2
# 0  LinearRegression     0.247018    0.011881    0.253299  -0.013317
# 1     Random Forest     0.243414    0.026295    0.250799  -0.003316

# %%
# Data Visualization of prediction results

import matplotlib.pyplot as plt
import numpy as np
plt.
plt.figure(figsize=(5, 5))
plt.scatter(x = y_train, y = lrTrainPredict, c="#7CAE00" ,alpha=0.3)

z = np.polyfit(y_train, lrTrainPredict, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
